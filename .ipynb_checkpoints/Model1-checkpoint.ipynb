# %%
# %reload_ext autoreload
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# import own scripts
import sys
sys.path.insert(0, '/src/')

# %autoreload 2
from utils import plot_multi, norm_dist_test, Model

# %%
# load numerical data
GDPC1 = pd.read_csv('data/GDPC1.csv')
FedFunds = pd.read_csv('data/FEDFUNDS.csv')

# load news articles
articles = pd.read_csv('data/Articles.csv', encoding = "ISO-8859-1")
articles1 = pd.read_csv('data/all-the-news/articles1.csv', encoding = "ISO-8859-1")
articles2 = pd.read_csv('data/all-the-news/articles2.csv', encoding = "ISO-8859-1")
articles3 = pd.read_csv('data/all-the-news/articles3.csv', encoding = "ISO-8859-1")

# %% [markdown]
# ## EDA: GDP
# ---
# > What's is the distribution of change in GDP? Over 1 period and over 2 periods?

# %%
# converting dates from `str` to `time series`
gdp = pd.DataFrame()
gdp['Date'] = pd.to_datetime(GDPC1['DATE'], infer_datetime_format=True)
gdp['GDP'] = GDPC1['GDPC1']
gdp.set_index('Date', inplace=True, drop=True)
gdp.head()
# Out:
#                  GDP
# Date
# 1947-01-01  2033.061
# 1947-04-01  2027.639
# 1947-07-01  2023.452
# 1947-10-01  2055.103
# 1948-01-01  2086.017

# %%
from pandas.plotting import autocorrelation_plot
series = gdp['GDP']
plt.figure(figsize=(12,10))
autocorrelation_plot(series)
plt.title('Autocorrelation Chart')
plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                  D.GDP   No. Observations:                  285
# Model:                 ARIMA(5, 1, 0)   Log Likelihood               -1576.329
# Method:                       css-mle   S.D. of innovations             61.042
# Date:                Tue, 11 Sep 2018   AIC                           3166.658
# Time:                        01:11:39   BIC                           3192.226
# Sample:                    04-01-1947   HQIC                          3176.908
#                          - 04-01-2018
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          57.9966      7.600      7.631      0.000      43.101      72.893
# ar.L1.D.GDP     0.3246      0.059      5.469      0.000       0.208       0.441
# ar.L2.D.GDP     0.1819      0.062      2.917      0.004       0.060       0.304
# ...

# %%
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot(figsize=(12,6), grid=True)
plt.title('ARMA Fit Residual Error Line Plot')
plt.show()

residuals.plot(kind='kde', figsize=(12,6), grid=True)
plt.title('ARMA Fit Residual Error Density Plot')
plt.show()
print(residuals.describe())
# Out:
#                 0
# count  285.000000
# mean     0.175367
# std     61.173909
# min   -348.889668
# 25%    -36.127985
# 50%      0.461553
# 75%     35.210414
# max    206.393388

# %%
from sklearn.metrics import mean_squared_error
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(12,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, observed=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# Out:
# predicted=10170.156713, observed=10188.954000
# predicted=10262.233211, observed=10327.019000
# predicted=10414.225418, observed=10387.382000
# predicted=10467.421070, observed=10506.372000
# predicted=10574.162574, observed=10543.644000
# predicted=10588.156883, observed=10575.100000
# predicted=10593.245609, observed=10665.060000
# predicted=10698.667479, observed=10737.478000
# predicted=10804.729566, observed=10817.896000
# predicted=10884.479610, observed=10998.322000
# predicted=11114.367363, observed=11096.976000
# predicted=11166.519390, observed=11212.205000
# predicted=11300.093513, observed=11284.587000
# predicted=11336.859047, observed=11472.137000
# predicted=11553.376897, observed=11615.636000
# predicted=11714.786735, observed=11715.393000
# predicted=11800.220523, observed=11832.486000
# predicted=11918.870550, observed=11942.032000
# predicted=12027.474074, observed=12091.614000
# predicted=12203.727380, observed=12287.000000
# ...

# %%
# plot
plt.figure(figsize=(12,6))
plt.plot(test)
plt.plot(predictions, color='red')
plt.title('ARIMA Rolling Forecast Line Plot')
plt.grid()
plt.legend(['observation','prediction'])
plt.show()

# %%
# gdp['GDP %Change 1P'] = gdp['GDP'].pct_change(periods=1)
predictions
# Out:
# [array([ 10170.15671284]),
#  array([ 10262.23321123]),
#  array([ 10414.22541783]),
#  array([ 10467.42106993]),
#  array([ 10574.16257359]),
#  array([ 10588.15688255]),
#  array([ 10593.24560856]),
#  array([ 10698.66747931]),
#  array([ 10804.72956589]),
#  array([ 10884.47961016]),
#  array([ 11114.36736256]),
#  array([ 11166.5193903]),
#  array([ 11300.09351293]),
#  array([ 11336.85904719]),
#  array([ 11553.37689746]),
#  array([ 11714.78673472]),
#  array([ 11800.22052325]),
#  array([ 11918.8705505]),
#  array([ 12027.47407445]),
#  array([ 12203.72738024]),
#  array([ 12423.59621776]),
#  array([ 12480.98373829]),
#  array([ 12591.02190973]),
#  array([ 12781.17090891]),
#  array([ 13029.11781165]),
#  array([ 13002.78445945]),
#  array([ 13277.55973106]),
#  array([ 13273.39510886]),
#  array([ 13339.08513238]),
#  array([ 13294.12149759]),
#  array([ 13304.06600611]),
#  array([ 13276.69280346]),
#  array([ 13310.62435594]),
#  array([ 13469.24490258]),
# ...

# %%
gdp1 = pd.DataFrame()
gdp1['dates'] = gdp.index[(gdp.shape[0] - len(predictions)):]
gdp1['gdp'], gdp1['gdp-ARIMA']  = test, [i[0] for i in predictions]

# add % changes
gdp1['%Chng-GDP'] = gdp1['gdp'].pct_change(periods=1)
gdp1['%Chng-GDP-ARIMA'] = gdp1['gdp-ARIMA'].pct_change(periods=1)

# plot
plt.figure(figsize=(10,10))
plt.scatter(gdp1['%Chng-GDP'], gdp1['%Chng-GDP-ARIMA'])
plt.grid()
plt.xlabel('%Change in GDP')
plt.ylabel('%Change in GDP-ARIMA')
plt.title('GDP vs GDP-ARIMA')
plt.show()

# %%
gdp1.head()
# Out:
#        dates        gdp     gdp-ARIMA  %Chng-GDP  %Chng-GDP-ARIMA
# 0 1994-01-01  10188.954  10170.156713        NaN              NaN
# 1 1994-04-01  10327.019  10262.233211   0.013550         0.009054
# 2 1994-07-01  10387.382  10414.225418   0.005845         0.014811
# 3 1994-10-01  10506.372  10467.421070   0.011455         0.005108
# 4 1995-01-01  10543.644  10574.162574   0.003548         0.010197

# %% [markdown]
# ## EDA: FedFunds Rate
# ---
# > What's the relevant date range? `1954-10-01` - `2018-04-01` <br>
# > What's the relationship between `FedFunds` & `GDP`? <br>
# > Is `FedFunds` rate a reliable leading indicator? <br>
# > Does the distribution of change in GDP change when accounting for `FedFunds`?

# %%
ff = pd.DataFrame()
ff['Date'] = pd.to_datetime(FedFunds['DATE'], infer_datetime_format=True)
ff['FedFunds'] = FedFunds['FEDFUNDS']
ff.head()
# Out:
#         Date  FedFunds
# 0 1954-07-01      0.80
# 1 1954-08-01      1.22
# 2 1954-09-01      1.06
# 3 1954-10-01      0.85
# 4 1954-11-01      0.83

# %%
# add columns for prev period
ff['FedFunds1P'] = pd.Series([np.nan] + list(FedFunds['FEDFUNDS'].iloc[:-1]))
ff['FedFunds2P'] = pd.Series([np.nan]*2 + list(FedFunds['FEDFUNDS'].iloc[:-2]))
ff['Delta1P'] = ff['FedFunds1P']/ff['FedFunds2P'] - 1
ff['Delta'] = ff['FedFunds']/ff['FedFunds1P'] - 1
                              
# Feature Engineering: rolling average going back 12 periods or 3 years
ff['FF_MA'] = -(ff['FedFunds1P'].dropna(axis=0).rolling(window=12).mean() - y)
ff.set_index('Date', inplace=True, drop=True)

# FedFund log
plot_multi(ff, 'year', figsize=(12,6), logy=True)
plt.show()

# %%
# is the `FedFunds 1P` normally distrubuted? More or less. We can manage Heterscadasticity with
# a boxcox transformation
y = ff['FF_MA'].dropna(axis=0).values
norm_dist_test(y, 'FedFunds1P')

# %%
ff.columns
# Out:
# Index(['FedFunds', 'FedFunds1P', 'FedFunds2P', 'Delta1P', 'Delta', 'FF_MA'], dtype='object')

# %%
# create a new data frame and drop rows with NaNs
df = gdp.join(ff[['FedFunds1P', 'FedFunds2P', 'Delta1P', 'Delta', 'FF_MA']]).dropna(axis=0)

# add label for 1 if > mean and 0 if < mean
df['label'] = [1]*len(df)
gdp_mean = np.mean(df['GDP %Change 1P'])
df['label'].where(df['GDP %Change 1P'] > gdp_mean,0, inplace=True)

df.head()
# Out:
#                  GDP  GDP %Change 1P  FedFunds1P  FedFunds2P   Delta1P  \
# Date
# 1955-07-01  2897.598        0.013505        1.64        1.43  0.146853
# 1955-10-01  2914.993        0.006003        2.18        1.96  0.112245
# 1956-01-01  2903.671       -0.003884        2.48        2.35  0.055319
# 1956-04-01  2927.665        0.008263        2.50        2.50  0.000000
# 1956-07-01  2925.035       -0.000898        2.71        2.75 -0.014545
#
#                Delta     FF_MA  label
# Date
# 1955-07-01  0.024390  0.425833      1
# 1955-10-01  0.027523  0.737500      0
# 1956-01-01 -0.012097  0.695000      0
# 1956-04-01  0.048000  0.430000      1
# 1956-07-01  0.014760  0.341667      0

# %%
df.tail()
# Out:
#                   GDP  GDP %Change 1P  FedFunds1P  FedFunds2P   Delta1P  \
# Date
# 2017-04-01  17995.150        0.007397        0.79        0.66  0.196970
# 2017-07-01  18120.843        0.006985        1.04        0.91  0.142857
# 2017-10-01  18223.758        0.005679        1.15        1.16 -0.008621
# 2018-01-01  18323.963        0.005499        1.30        1.16  0.120690
# 2018-04-01  18507.200        0.010000        1.51        1.42  0.063380
#
#                Delta     FF_MA  label
# Date
# 2017-04-01  0.139241  0.310000      0
# 2017-07-01  0.105769  0.415833      0
# 2017-10-01  0.000000  0.336667      0
# 2018-01-01  0.084615  0.298333      0
# 2018-04-01  0.119205  0.321667      1

# %% [markdown]
# # Model: RandomForest
# ---

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import confusion_matrix, roc_curve, auc

# %%
df.head()
# Out:
#                  GDP  GDP %Change 1P  FedFunds1P  FedFunds2P   Delta1P  \
# Date
# 1955-07-01  2897.598        0.013505        1.64        1.43  0.146853
# 1955-10-01  2914.993        0.006003        2.18        1.96  0.112245
# 1956-01-01  2903.671       -0.003884        2.48        2.35  0.055319
# 1956-04-01  2927.665        0.008263        2.50        2.50  0.000000
# 1956-07-01  2925.035       -0.000898        2.71        2.75 -0.014545
#
#                Delta     FF_MA  label
# Date
# 1955-07-01  0.024390  0.425833      1
# 1955-10-01  0.027523  0.737500      0
# 1956-01-01 -0.012097  0.695000      0
# 1956-04-01  0.048000  0.430000      1
# 1956-07-01  0.014760  0.341667      0

# %%
X = df
_ = X.pop('GDP %Change 1P')
y = X.pop('label')
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2)
cf = RandomForestClassifier(n_estimators=100, n_jobs=-1)
cf.fit(x_train, y_train)
y_pred = cf.predict(x_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[15,  9],
#        [15, 12]])

# %%
cf.feature_importances_
# Out:
# array([ 0.20440278,  0.20889423,  0.19024038,  0.19210716,  0.20435545])

# %%
# feat_imp = pd.Series(cf.feature_importances_, X.columns).sort_values(ascending=False)

# %%
y_prob = cf.predict_proba(x_test).T[1]
fpr, tpr, threshold = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## Decisions from EDA
# > 1.

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

x = range(0,len(y))
y = df['FedFunds 1P']

plt.plot(x, y, x, yd,'-g')
plt.show()

# %%
x = x

# %%
df1 = pd.DataFrame()
df1['FedFunds'] = y
df1['Poly'] = yp
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-2e82fcbb4366> in <module>()
#       1 df1 = pd.DataFrame()
#       2 df1['FedFunds'] = y
# ----> 3 df1['Poly'] = yp
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#    2399
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2566
# ...

# %%
yp
# Out:
# array([ -5.26148881e-04,   1.19739459e-01,   9.83349758e-01])

# %%
plot_multi(y, 'year', figsize=(12,6))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-251dd967dba0> in <module>()
# ----> 1 plot_multi(y, 'year', figsize=(12,6))
#
# ~/CloudStation/Job Search/2018/HyperGiant/HG/utils.py in plot_multi(data, xlabel, cols, spacing, **kwargs)
#      30
#      31     # Get default color style from pandas - can be changed to any other color list
# ---> 32     if cols is None: cols = data.columns
#      33     if len(cols) == 0: return
#      34     colors = getattr(getattr(plotting, '_style'), '_get_standard_colors')(num_colors=len(cols))
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3075         if (name in self._internal_names_set or name in self._metadata or
#    3076                 name in self._accessors):
# -> 3077             return object.__getattribute__(self, name)
#    3078         else:
# ...
