# %%
# %reload_ext autoreload
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import cross_val_score

from multiprocessing import Pool
from tqdm import tqdm_notebook

import matplotlib.pyplot as plt
# %matplotlib inline


# import own scripts
import sys
sys.path.insert(0, '/src/')

# %autoreload 2
from utils import clean_gdp, gdp_change, aggregate_sentiment, Model

# %% [markdown]
# ## Incorporate Sentiment Analysis
# ---

# %%
# load data
sentiment = pd.read_csv('src/results/sentiment.csv')
gdp = gdp_change(clean_gdp(pd.read_csv('data/GDPC1.csv')))

# %%
# merge aggregated sentiment 
df = aggregate_sentiment(gdp, sentiment).set_index(gdp.iloc[1:].index).fillna(0)

# %%
# add labels
df['label'] = list(gdp['%Change']>0)[1:]

# %%
# model
mod = Model()
predictors = list(df.columns)[:-1]
target = 'label'
mod = mod.modelfit(RandomForestClassifier(), df, predictors, target, performCV=True, printFeatureImportance=True, cv_folds=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-26c93dbc6bf3> in <module>()
#       3 predictors = list(df.columns)[:-1]
#       4 target = 'label'
# ----> 5 mod = mod.modelfit(RandomForestClassifier(), df, predictors, target, performCV=True, printFeatureImportance=True, cv_folds=5)
#
# ~/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py in modelfit(self, alg, dtrain, predictors, target, performCV, printFeatureImportance, cv_folds)
#      89         #Perform cross-validation:
#      90         if performCV:
# ---> 91             cv_score = cross_val_score(alg, dtrain[predictors], dtrain[target], cv=cv_folds, scoring='roc_auc')
#      92
#      93         #Print model report:
#
# NameError: name 'cross_val_score' is not defined

# %%
list(gdp['%Change']>0)[1:]
# Out:
# 286

# %%
merged.head()
# Out:
#                           GDP   %Change  Topic 0 Avg. Sentiment  \
# Date
# 1947-01-01 00:00:00  2033.061       NaN                     NaN
# 1947-04-01 00:00:00  2027.639 -0.002667                     NaN
# 1947-07-01 00:00:00  2023.452 -0.002065                     NaN
# 1947-10-01 00:00:00  2055.103  0.015642                     NaN
# 1948-01-01 00:00:00  2086.017  0.015043                     NaN
#
#                      Topic 1 Avg. Sentiment  Topic 2 Avg. Sentiment  \
# Date
# 1947-01-01 00:00:00                     NaN                     NaN
# 1947-04-01 00:00:00                     NaN                     NaN
# 1947-07-01 00:00:00                     NaN                     NaN
# 1947-10-01 00:00:00                     NaN                     NaN
# 1948-01-01 00:00:00                     NaN                     NaN
#
#                      Topic 3 Avg. Sentiment  Topic 4 Avg. Sentiment  \
# Date
# 1947-01-01 00:00:00                     NaN                     NaN
# 1947-04-01 00:00:00                     NaN                     NaN
# 1947-07-01 00:00:00                     NaN                     NaN
# 1947-10-01 00:00:00                     NaN                     NaN
# 1948-01-01 00:00:00                     NaN                     NaN
#
#                      Topic 5 Avg. Sentiment  Topic 6 Avg. Sentiment  \
# Date
# 1947-01-01 00:00:00                     NaN                     NaN
# 1947-04-01 00:00:00                     NaN                     NaN
# 1947-07-01 00:00:00                     NaN                     NaN
# 1947-10-01 00:00:00                     NaN                     NaN
# 1948-01-01 00:00:00                     NaN                     NaN
#
#                      Topic 7 Avg. Sentiment          ...           \
# Date                                                 ...
# 1947-01-01 00:00:00                     NaN          ...
# 1947-04-01 00:00:00                     NaN          ...
# 1947-07-01 00:00:00                     NaN          ...
# 1947-10-01 00:00:00                     NaN          ...
# 1948-01-01 00:00:00                     NaN          ...
#
#                      Topic 90 Topic Count  Topic 91 Topic Count  \
# Date
# 1947-01-01 00:00:00                   NaN                   NaN
# 1947-04-01 00:00:00                   NaN                   NaN
# 1947-07-01 00:00:00                   NaN                   NaN
# 1947-10-01 00:00:00                   NaN                   NaN
# 1948-01-01 00:00:00                   NaN                   NaN
#
#                      Topic 92 Topic Count  Topic 93 Topic Count  \
# Date
# 1947-01-01 00:00:00                   NaN                   NaN
# 1947-04-01 00:00:00                   NaN                   NaN
# 1947-07-01 00:00:00                   NaN                   NaN
# 1947-10-01 00:00:00                   NaN                   NaN
# 1948-01-01 00:00:00                   NaN                   NaN
#
#                      Topic 94 Topic Count  Topic 95 Topic Count  \
# Date
# 1947-01-01 00:00:00                   NaN                   NaN
# 1947-04-01 00:00:00                   NaN                   NaN
# 1947-07-01 00:00:00                   NaN                   NaN
# 1947-10-01 00:00:00                   NaN                   NaN
# 1948-01-01 00:00:00                   NaN                   NaN
#
#                      Topic 96 Topic Count  Topic 97 Topic Count  \
# Date
# 1947-01-01 00:00:00                   NaN                   NaN
# 1947-04-01 00:00:00                   NaN                   NaN
# 1947-07-01 00:00:00                   NaN                   NaN
# 1947-10-01 00:00:00                   NaN                   NaN
# 1948-01-01 00:00:00                   NaN                   NaN
#
#                      Topic 98 Topic Count  Topic 99 Topic Count
# Date
# 1947-01-01 00:00:00                   NaN                   NaN
# 1947-04-01 00:00:00                   NaN                   NaN
# 1947-07-01 00:00:00                   NaN                   NaN
# 1947-10-01 00:00:00                   NaN                   NaN
# 1948-01-01 00:00:00                   NaN                   NaN
#
# [5 rows x 202 columns]

# %%
b = 
b.shape
# Out:
# (285, 200)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-59de7fbf51c6> in <module>()
# ----> 1 agg.head()
#
# AttributeError: 'list' object has no attribute 'head'
