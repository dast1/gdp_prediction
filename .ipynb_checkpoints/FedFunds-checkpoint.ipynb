# %%
# %reload_ext autoreload
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# import own scripts
import sys
sys.path.insert(0, '/src/')

# %autoreload 2
from utils import plot_multi, norm_dist_test, Model, clean_gdp, clean_ff, test_stationarity, decompose_trend,grid_search_SARIMA

# %%
# load data
gdp = clean_gdp(pd.read_csv('data/GDPC1.csv'))
ff = clean_ff(pd.read_csv('data/FEDFUNDS.csv'))

# %%
gdp['rolmean'] = gdp['GDP'].rolling(4).mean()
gdp['rolstd'] = gdp['GDP'].rolling(4).std()

# %% [markdown]
# ## Achieve stationarity
# ---
# Define Stationarity:
# 1. Constant mean,
# 2. Constant variance,
# 3. Autocovariance that does not depend on time
#
# Use `Dickey-Fuller Test`: This is one of the statistical tests for checking stationarity. Here the **null hypothesis is that the TS is non-stationary**. The test results comprise of a Test Statistic and some Critical Values for difference confidence levels. If the ‘Test Statistic’ is less than the ‘Critical Value’, we can reject the null hypothesis and say that the series is stationary.

# %%
test_stationarity(gdp, 'GDP', window = 4)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   2.915394
# p-value                          1.000000
# #Lags Used                      12.000000
# Number of Observations Used    273.000000
# Critical Value (1%)             -3.454533
# Critical Value (5%)             -2.872186
# Critical Value (10%)            -2.572443
# dtype: float64

# %% [markdown]
# > p-value = 1, `GDP` data is not a stationary data. Also, `Rolling Std` is NOT constant but **increasing and flares out**

# %%
test_stationarity(ff, 'FedFundsRate',12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.765412
# p-value                          0.063387
# #Lags Used                      17.000000
# Number of Observations Used    751.000000
# Critical Value (1%)             -3.439087
# Critical Value (5%)             -2.865396
# Critical Value (10%)            -2.568823
# dtype: float64

# %% [markdown]
# > Although, p-value is close to 0.05, it's still clear that the `Fed Funds` data is not stationary because `Rolling Std` is also NOT constant.
#
# We can proceed with using `Seasonal Decomposition`. This is a quick and common practice to assess if time series data has a underlying seasonality. The default parameters used here generate a trend.

# %% [markdown]
# ## Analyze Seasonal Decomposition of Fed Funds Data
# ---
# > **additive**: y(t) = Level + Trend + Seasonality + Noise <br>
# > **multiplicative**:  y(t) = Level x Trend x Seasonality x Noise <br>
# > **Decision**: `additive` makes more sense becasue `FedFunds` is range bound... but let's see the residual noise.

# %%
decompose_trend(ff, 'FedFundsRate', model='additive')
# Out:
# Dickey–Fuller test: p=0.063387

# %%
print('Fed Funds: Multiplicative')
y = ff['FedFundsRate']
print("Dickey–Fuller test: p=%f" % adfuller(y)[1])
ff_multiplicative = seasonal_decompose(y, model='multiplicative').plot()
# Out:
# Fed Funds: Multiplicative
# Dickey–Fuller test: p=0.063387

# %%
def decompose_trend(df, label):
    y = df[label]
    print('GDP: Multiplicative - w/ Box-Cox Transformation')
    print("Dickey–Fuller test: p=%f" % adfuller(y)[1])
    _ = seasonal_decompose(ff['box-cox'], model='additive').plot()
decompose_trend(ff, 'FedFundsRate')
# Out:
# GDP: Multiplicative - w/ Box-Cox Transformation
# Dickey–Fuller test: p=0.063387

# %%
y = ff['FedFundsRate']
y_bc, lmbda = stats.boxcox(y)
ff['box-cox'] = y_bc
print('GDP: Multiplicative - w/ Box-Cox Transformation')
print("Dickey–Fuller test: p=%f" % adfuller(y_bc)[1])
_ = seasonal_decompose(ff['box-cox'], model='additive').plot()
# Out:
# GDP: Multiplicative - w/ Box-Cox Transformation
# Dickey–Fuller test: p=0.160915

# %% [markdown]
# ## Analyze Seasonal Decomposition of GDP data
# ---
# > **additive**: y(t) = Level + Trend + Seasonality + Noise <br>
# > **multiplicative**:  y(t) = Level x Trend x Seasonality x Noise <br>
# > **Decision**: `multiplicative` makes more sense becasue `GDP` has a ~2% YoY Growth Target... but let's see the residual noise.

# %%
print('GDP: Additive')
y = gdp['GDP']
print("Dickey–Fuller test: p=%f" % adfuller(y)[1])
gdp_additive = seasonal_decompose(y, model='additive').plot()
# Out:
# GDP: Additive
# Dickey–Fuller test: p=1.000000

# %%
print('GDP: Multiplicative')
y = gdp['GDP']
print("Dickey–Fuller test: p=%f" % adfuller(y)[1])
gdp_multiplicative = seasonal_decompose(y, model='multiplicative').plot()
# Out:
# GDP: Multiplicative
# Dickey–Fuller test: p=1.000000

# %% [markdown]
# There is a noticeable drop in GDP Residual Noise after `1980`. [Here](https://www.frbsf.org/economic-research/publications/economic-letter/2005/september/why-has-output-become-less-volatile/) is why?

# %% [markdown]
# ## Box-Cox transformation on `FedFunds`
# ---

# %%
# Out:
# GDP: Multiplicative - w/ Box-Cox Transformation
# Dickey–Fuller test: p=0.160915

# %% [markdown]
# ## Box-Cox transformation on `GDP`
# ---

# %%
y = gdp['gdp_box']
gdp['box-cox'], lmbda = stats.boxcox(y)
print('GDP: Multiplicative - w/ Box-Cox Transformation')
print("Dickey–Fuller test: p=%f" % adfuller(y)[1])
gdp_multiplicative_bc = seasonal_decompose(y, model='multiplicative').plot()
# Out:
# GDP: Multiplicative - w/ Box-Cox Transformation
# Dickey–Fuller test: p=0.781648
