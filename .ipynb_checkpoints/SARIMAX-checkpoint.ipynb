# %%
# %reload_ext autoreload
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

from scipy import stats
import statsmodels.api as sm
import scipy

# import own scripts
import sys
sys.path.insert(0, '/src/')

# %autoreload 2
from utils import plot_multi, norm_dist_test, Model, clean_gdp, grid_search_SARIMA, \
test_stationarity, decompose_trend, plot_resid_SARIMA, one_step_ahead_forecast, dynamic_forecast, norm_pdf

# %%
# load data
gdp = clean_gdp(pd.read_csv('data/GDPC1.csv'))
ff = pd.read_csv('src/results/ff.csv', index_col='Date')

# %%
test_stationarity(gdp, 'GDP',12)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   2.915394
# p-value                          1.000000
# #Lags Used                      12.000000
# Number of Observations Used    273.000000
# Critical Value (1%)             -3.454533
# Critical Value (5%)             -2.872186
# Critical Value (10%)            -2.572443
# dtype: float64

# %%
decompose_trend(gdp, 'GDP', model='multiplicative')
# Out:
# Dickey–Fuller test: p=1.000000

# %%
gdp['box_cox'], _ = stats.boxcox(gdp['GDP'])
decompose_trend(gdp, 'box_cox', model='multiplicative')
# Out:
# Dickey–Fuller test: p=0.781648

# %%
gdp_sarima_model = grid_search_SARIMA(gdp['GDP'])
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=3063.651, BIC=3081.698, Fit time=0.885 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=3285.895, BIC=3293.114, Fit time=0.034 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=3137.762, BIC=3152.200, Fit time=0.792 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=3078.007, BIC=3092.445, Fit time=0.741 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=3062.194, BIC=3083.851, Fit time=1.685 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 0, 12); AIC=3133.434, BIC=3151.481, Fit time=1.362 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=3062.454, BIC=3087.720, Fit time=7.878 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=3245.692, BIC=3260.130, Fit time=0.266 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=3064.441, BIC=3093.317, Fit time=8.264 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=3077.793, BIC=3095.840, Fit time=1.922 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=3062.337, BIC=3087.603, Fit time=2.538 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 1, 12); AIC=3066.873, BIC=3084.920, Fit time=1.266 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=3061.698, BIC=3086.964, Fit time=1.695 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 1, 12); AIC=3064.654, BIC=3097.139, Fit time=4.486 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=3063.686, BIC=3085.343, Fit time=1.600 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 1, 12); AIC=3061.763, BIC=3090.639, Fit time=11.786 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=3131.707, BIC=3153.364, Fit time=1.930 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=3060.797, BIC=3089.673, Fit time=12.450 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=3064.927, BIC=3090.193, Fit time=15.003 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(1, 1, 2, 12); AIC=3067.592, BIC=3100.077, Fit time=24.386 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=3078.418, BIC=3100.074, Fit time=47.506 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 2, 12); AIC=3087.674, BIC=3123.769, Fit time=22.660 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=3061.613, BIC=3086.879, Fit time=5.680 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=3064.216, BIC=3096.701, Fit time=17.039 seconds
# Total fit time: 193.868 seconds
# 3060.7969932677556

# %%
gdp['SARIMA'] = gdp_sarima_model.predict_in_sample()
decompose_trend(gdp, 'SARIMA', model='multiplicative')
# Out:
# Dickey–Fuller test: p=1.000000

# %% [markdown]
# ## Rebuild ARIMA and Incorporate `FedFunds`
# ---
# > integrate optimal `order` and `seasonal_order` parameters <br>
# > integrate exog array with `FedFund` SARIMA

# %%
merged = gdp.join(ff).dropna(axis=0)
merged.head()
# Out:
#                  GDP  FedFundsRate   rolmean    rolstd   box_cox    SARIMA
# Date
# 1955-07-01  2897.598          1.68  1.287500  0.268061  0.592613  2.038641
# 1955-10-01  2914.993          2.24  1.558333  0.406601  0.994172  2.145926
# 1956-01-01  2903.671          2.45  1.873333  0.453558  1.131572  2.438375
# 1956-04-01  2927.665          2.62  2.169167  0.398279  1.238556  2.528247
# 1956-07-01  2925.035          2.75  2.457500  0.242866  1.318053  2.691424

# %%
exog = np.array(merged['SARIMA'])

# %%
gdp_sarimax_model = grid_search_SARIMA(merged['GDP'], exog=exog)
# Out:
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# [autoreload of utils failed: Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/dastanaitzhanov1/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py", line 339
#     print(stepwise_model.aic())
#         ^
# SyntaxError: invalid syntax
# ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-321-eba3768ac8b5> in <module>()
# ----> 1 gdp_sarimax_model = grid_search_SARIMA(merged['GDP'], exog=merged['SARIMA'])
#
# ~/CloudStation/Job Search/2018/HyperGiant/gdp_prediction/utils.py in grid_search_SARIMA(timeseries, exog)
#     336                            error_action='ignore',
#     337                            suppress_warnings=True,
# --> 338                            stepwise=True)
#     339     print(stepwise_model.aic())
#     340     return stepwise_model
#
# /anaconda3/lib/python3.6/site-packages/pyramid/arima/auto.py in auto_arima(y, exogenous, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, transparams, solver, maxiter, disp, callback, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, **fit_args)
#     447     xx = y.copy()
#     448     if exogenous is not None:
# --> 449         lm = LinearRegression().fit(exogenous, y)
#     450         xx = y - lm.predict(exogenous)
#     451
#
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     439                     "Reshape your data either using array.reshape(-1, 1) if "
#     440                     "your data has a single feature or array.reshape(1, -1) "
# --> 441                     "if it contains a single sample.".format(array))
#     442             array = np.atleast_2d(array)
#     443             # To ensure that array flags are maintained
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 2.03864146e+00  2.14592601e+00  2.43837503e+00  2.52824668e+00
#   2.69142432e+00  3.01305167e+00  2.89909200e+00  2.98635433e+00
#   3.07355748e+00  3.47757520e+00  2.80369395e+00  1.26628915e+00
#   1.22355284e+00  1.62568472e+00  2.30382598e+00  3.05978541e+00
#   3.55756978e+00  3.82743420e+00  3.89182812e+00  3.86851873e+00
#   3.00992079e+00  2.49146516e+00  1.71527647e+00  1.65196157e+00
#   1.43213503e+00  1.66939636e+00  2.12312884e+00  3.08356688e+00
#   2.78801058e+00  2.84724892e+00  2.81726345e+00  3.00837740e+00
#   2.84349007e+00  3.48072792e+00  3.24872628e+00  3.43526837e+00
#   3.36923474e+00  3.48927049e+00  3.86269213e+00  4.05258868e+00
#   3.90898146e+00  4.05049426e+00  4.34988693e+00  4.64879901e+00
#   5.13569527e+00  5.37609632e+00  5.15378505e+00  4.31212629e+00
#   3.90372394e+00  4.05863230e+00  4.56556830e+00  5.19865754e+00
#   5.96478392e+00  5.76572531e+00  6.05474795e+00  6.78406086e+00
#   8.72620565e+00  9.07366187e+00  8.95614403e+00  7.24358964e+00
#   7.47354626e+00  6.32173037e+00  4.64820515e+00  3.76008471e+00
#   4.89792662e+00  5.60663255e+00  3.81391546e+00  4.17019049e+00
#   4.39338816e+00  4.94944168e+00  5.37867965e+00  7.36690305e+00
#   8.53923148e+00  1.10455906e+01  9.68753523e+00  9.76848681e+00
#   1.19063751e+01  1.14075401e+01  8.09107176e+00  5.38871794e+00
#   5.71274513e+00  6.39082358e+00  5.25260481e+00  5.01626210e+00
#   5.51216101e+00  5.19441146e+00  4.41291185e+00  4.86242938e+00
#   5.39291635e+00  6.09175936e+00  6.43661779e+00  6.94519064e+00
#   7.68306472e+00  8.47394030e+00  9.87735528e+00  1.02543040e+01
#   1.03171898e+01  1.14581785e+01  1.41659790e+01  1.85500013e+01
#   1.00098726e+01  1.09771915e+01  1.96787838e+01  1.48995834e+01
#   1.90835785e+01  1.51672909e+01  1.21907784e+01  1.44440820e+01
#   1.41758242e+01  1.08249110e+01  8.60898731e+00  8.99146326e+00
#   9.33140669e+00  9.56091789e+00  9.44858661e+00  1.02034595e+01
#   1.13438505e+01  1.11058849e+01  7.82770557e+00  8.73896564e+00
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      3.1207      1.385      2.253      0.024       0.406       5.835
# ar.L1          0.4479      0.173      2.592      0.010       0.109       0.787
# ma.L1         -0.1651      0.184     -0.899      0.369      -0.525       0.195
# ma.L2          0.1714      0.068      2.534      0.011       0.039       0.304
# ar.S.L12      -0.7059      0.242     -2.920      0.003      -1.180      -0.232
# ma.S.L12      -0.3627      0.253     -1.432      0.152      -0.859       0.134
# ma.S.L24      -0.5521      0.276     -2.003      0.045      -1.092      -0.012
# sigma2      3646.1503    298.915     12.198      0.000    3060.287    4232.014
# ===================================================================================
# Ljung-Box (Q):                       48.61   Jarque-Bera (JB):               255.80
# Prob(Q):                              0.16   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.98   Skew:                            -0.82
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# plot residual errors
plot_resid_SARIMA(model1, gdp)
# Out:
#          residuals
# count   286.000000
# mean      4.213989
# std     145.841145
# min    -937.840922
# 25%     -27.715655
# 50%       0.646710
# 75%      39.056539
# max    2029.747391

# %%
model2 = model2.fit()
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   % freq, ValueWarning)
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                GDP   No. Observations:                  256
# Model:             SARIMAX(1, 1, 2)x(1, 1, 2, 12)   Log Likelihood               -1220.103
# Date:                            Wed, 12 Sep 2018   AIC                           2456.206
# Time:                                    18:56:12   BIC                           2483.208
# Sample:                                07-01-1954   HQIC                          2467.114
#                                      - 04-01-2018
# Covariance Type:                              opg
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# FedFundsRate     7.2274      2.858      2.529      0.011       1.627      12.828
# ar.L1            0.5535      0.154      3.602      0.000       0.252       0.855
# ma.L1           -0.2772      0.165     -1.677      0.094      -0.601       0.047
# ma.L2            0.1724      0.082      2.095      0.036       0.011       0.334
# ar.S.L12        -0.7187      0.220     -3.268      0.001      -1.150      -0.288
# ma.S.L12        -0.3067      0.243     -1.263      0.207      -0.783       0.169
# ma.S.L24        -0.5067      0.237     -2.142      0.032      -0.970      -0.043
# sigma2        4520.8704    391.897     11.536      0.000    3752.767    5288.974
# ===================================================================================
# Ljung-Box (Q):                       43.21   Jarque-Bera (JB):               113.12
# Prob(Q):                              0.34   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.64   Skew:                            -0.70
# Prob(H) (two-sided):                  0.04   Kurtosis:                         6.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
plot_resid_SARIMA(model2, gdp)
# Out:
#          residuals
# count   256.000000
# mean     12.414900
# std     206.986595
# min   -1130.898736
# 25%     -25.384818
# 50%       8.324401
# 75%      47.492227
# max    2676.819085

# %%
one_ste_ahead_forecast(model2, gdp,'2000','2007-01-01')

# %%
dynamic_forecast(model2, gdp, '2000', '2007-01-01')

# %%
# Change in AIC
[model1.aic(), model2.aic]
# Out:
# [3060.7969932677556, 2456.20552754132]

# %% [markdown]
# ## Hypothesis Testing of Residual Errors
# ---
# > H0: mu1 = mu2 <br>
# > H1: mu1 != mu2 <br>
# > alpha = .05

# %%
plt.figure(figsize=(12,6))
norm_dist_test(model1.resid(), "Model 1 Residuals")
norm_dist_test(model2.resid, "Model 2 Residuals")
plt.title("mu1 = {}, mu2 = {}".format(str(np.mean(model1.resid())),str(np.mean(model2.resid))))
# Out:
# Text(0.5,1,'mu1 = 4.213988943703313, mu2 = 12.414900433940106')

# %%
# Use KS test to see if there is a difference
scipy.stats.ks_2samp(model1.resid(), model2.resid)
# Out:
# Ks_2sampResult(statistic=0.10596044580419584, pvalue=0.08997173453527182)

# %% [markdown]
# KS test p-value = .09 in the distribution of Residual Errors. Therefore, failed to reject the H0, i.e **`model_1` and `model_2` residuals are not statistically different.**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(-.1,.1), copy=True)

# %%
source = np.array([3060.7969932677556, 2456.20552754132]).reshape(-1, 1)
scaler.fit_transform(source)
# Out:
# array([[ 0.1],
#        [-0.1]])

# %%
a = []
